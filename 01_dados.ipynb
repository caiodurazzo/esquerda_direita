# %% [markdown]
# ## Dados

# %% [markdown]
# Nesse notebook os dados para análise são reconstruídos a partir da tabela 2.6 (página 84) do livro.

# %%
import pandas as pd
from utils.save_csv import save_csv

# %%
dados = pd.DataFrame({
    "Esquerda": [0.698 * 280, 0.302 * 280],
    "Centro": [0.418 * 833, 0.582 * 833],
    "Direita": [0.209 * 532, 0.791 * 532]}, 
    index = ["Lula", "Collor"])

dados = dados.round().astype(int)

print(dados)
# Out:
#         Esquerda  Centro  Direita
# Lula         195     348      111
# Collor        85     485      421

# %%
save_csv(dados, "dados.csv")
# Out:
# Base salva em data\dados.csv
