# %% [markdown]
# ## Dados

# %% [markdown]
# Nesse notebook os dados para análise são reconstruídos a partir da tabela 2.6 (página 84) do livro.

# %% [markdown]
# Devido a possíveis arredondamentos no material original, os valores podem não corresponder exatamente aos dados originais utilizados pelo autor.

# %% [markdown]
# Portanto, os resultados devem ser interpretados como uma replicação aproximada da análise.

# %%
import pandas as pd
from utils.save_csv import save_csv

# %%
totais = {
    "Esquerda": 280,
    "Centro": 833,
    "Direita": 532
}

percentuais = {
    "Lula": [0.698, 0.418, 0.209],
    "Collor": [0.302, 0.582, 0.791]
}

dados = pd.DataFrame(percentuais, index=totais.keys()).T

for col in dados.columns:
    dados[col] = dados[col] * totais[col]

dados = dados.round().astype(int)

print(dados)
# Out:
#         Esquerda  Centro  Direita
# Lula         195     348      111
# Collor        85     485      421

# %%
save_csv(dados, "dados.csv")
# Out:
# Base salva em data\dados.csv
